# %% [markdown]
# ## Automate news article collection for training the model using web scraper
# ##Factly other checks

# %% [markdown]
# #### Import libraries for web scraping

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
url = "https://factly.in/category/other-fact-checks/"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req)

# %%
html = webpage.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# The HTML document of the page was analysed and as a result the below logic is applied to scrape the articles.

# %%
articles = [article.find("h2").find("a").get("href") for article in soup.find(class_ = "col-8 main-content").find_all("article")]

# %%
articles
# Out:
# ['https://factly.in/fact-check-trump-is-wrong-about-indias-spending-on-a-library-in-afghanistan-being-equal-to-5-hours-of-u-s-spending/',
#  'https://factly.in/fact-checking-congress-partys-claims-about-public-expenditure-on-education-health/',
#  'https://factly.in/fact-check-has-msp-for-wheat-doubled-during-the-upa/',
#  'https://factly.in/fact-check-has-there-been-a-considerable-increase-in-defence-sector-expenditure-during-the-upa/',
#  'https://factly.in/fact-check-did-the-upa-construct-only-25-lakh-houses-in-their-last-4-years/',
#  'https://factly.in/fact-check-in-whose-tenure-did-exports-grow-faster-2/',
#  'https://factly.in/fact-check-how-much-did-the-modi-government-pay-for-the-upa-era-oil-bonds/',
#  'https://factly.in/fact-check-in-whose-tenure-did-msp-increase-by-a-greater-percentage-2/',
#  'https://factly.in/fact-check-have-deposits-by-indians-in-swiss-banks-decreased/',
#  'https://factly.in/fact-check-in-whose-tenure-did-exports-grow-faster/']

# %%
for article_url in articles:
    if "review:" not in article_url and "data:" not in article_url and "explainer:" not in article_url:
        article_req = Request(article_url, headers={'User-Agent': 'Mozilla/5.0'})
        article_page = urlopen(article_req)
        article_html = article_page.read().decode("utf-8")
        article_soup = BeautifulSoup(article_html, "html.parser")
        article_content = article_soup.find(class_ = "post-content-right").get_text()
        article_nature = article_soup.find("blockquote").find("strong").get_text()
        print(f"Article: \n{article_content}\n")
        print(f"Nature of the article: {article_nature}")
        print("\n\n")
# Out:
# Article:
# ...
